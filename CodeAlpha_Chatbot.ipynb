# %%
def chatbot():
    print("Thanku for using my Chatbot.")

print("Chatbot: Hello.  Type 'byy' to exist:")
while True:
    user = input("You:  ").lower().strip()

    if user == "hello":
        print("Chatbot: hiii")
        
    elif user == "how are you":
        print("Chatbot: I'm fine, Thankyou!")

    elif user == "what is your name":
        print("Chatbot: i am a small chatbot.")

    elif user == "good morning":
        print("Chatbot: Good morning!, Have a nice day.")

    elif user == "good afternoon":
        print("Chatbot: Good afternoon.")

    elif user == "good evening":
        print("Chatbot: Good evening")
        
    elif user == "byy":
        print("Chatbot: Goodbye.")
        break

    else:
        print("Chatbot: Sorry i don't understand.")
        
chatbot()
# Out:
# Chatbot: Hello.  Type 'byy' for exist:
# You:   hello
# Chatbot: hiii
# You:   byy
# Chatbot: Goodbye.
# Thanku for using my Chatbot.
